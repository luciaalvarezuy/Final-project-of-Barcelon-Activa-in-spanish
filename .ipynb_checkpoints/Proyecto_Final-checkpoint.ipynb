# %% [markdown]
# El siguiente trabajo es parte del curso "Data Science" realizado en Barcelona Activa en el año 2022.
# El trabajo se realiza con un dataframe con datos referidos a..
#
# Se recomienda acceder a xx, para xxx
#
# El trabajo está segmentado en x partes.
# Primero, se carga el dataframe a trabajar y se realiza una breve descripción de todas las variables.
#
#
# Segundo,
#
# Tercero

# %% [markdown]
# A continuación, se carga las librerias necesarias para este ejercicio y el dataframe.

# %%
#Cargar los paquetes a usar
import pandas as pd
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
from factor_analyzer import FactorAnalyzer
from factor_analyzer.factor_analyzer import calculate_bartlett_sphericity
from factor_analyzer.factor_analyzer import calculate_kmo
import numpy as np
from sklearn.linear_model import LinearRegression
from statsmodels.stats.outliers_influence import variance_inflation_factor
from scipy import stats
import pingouin as pg
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
from sklearn.metrics import r2_score
from sklearn.tree import plot_tree


#from sklearn.datasets import load_iris
#from sklearn import preprocessing 
#from sklearn.cluster import KMeans
#from kneed import KneeLocator
#import scipy.cluster.hierarchy as shc
#from sklearn.metrics import silhouette_score
#from sklearn.cluster import AgglomerativeClustering
#from sklearn.tree import DecisionTreeClassifier 
#import six
#from six import StringIO
#import sys
#from sklearn.tree import export_graphviz
#import pydotplus
#from IPython.display import Image

# %% [markdown]
# # Primera parte
# Cargar la base de datos y breve descripción de los datos

# %%
filename = 'C:/Users/Lucía Alvarez/OneDrive - psico.edu.uy/00 Barcelona activa/Dataframe_proyecto.csv'
df = pd.read_csv(filename, sep=";",encoding="utf8", na_values = 999 ) 
df.head(10)
# Out:
#     ID  CFC_1  CFC_2  CFC_3_I  CFC_4_I  CFC_5_I  CFC_6  CFC_7  CFC_8  CFC_9_I  \
# 0  213      3      6        4        5        2      5      3      5        3
# 1   14      6      6        1        1        1      4      7      6        1
# 2   22      7      1        1        1        2      4      1      1        7
# 3   27      4      3        4        5        2      5      6      5        2
# 4   29      7      2        1        2        1      6      7      7        2
# 5   32      7      4        2        1        1      3      2      4        3
# 6   35      3      2        6        1        1      6      6      5        5
# 7   36      4      6        2        2        2      5      5      5        2
# 8   37      5      5        1        4        1      1      1      5        5
# 9   39      7      7        1        5        7      7      2      7        1
#
#    ...  Altura  Peso  Edad  Educacion  Ingreso_mensual  Sexo  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 282 entries, 0 to 281
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   282 non-null    int64
#  1   CFC_1                282 non-null    int64
#  2   CFC_2                282 non-null    int64
#  3   CFC_3_I              282 non-null    int64
#  4   CFC_4_I              282 non-null    int64
#  5   CFC_5_I              282 non-null    int64
#  6   CFC_6                282 non-null    int64
#  7   CFC_7                282 non-null    int64
#  8   CFC_8                282 non-null    int64
#  9   CFC_9_I              282 non-null    int64
#  10  CFC_10_I             282 non-null    int64
#  11  CFC_11_I             282 non-null    int64
#  12  CFC_12_I             282 non-null    int64
#  13  CFC_13               282 non-null    int64
#  14  CFC_14               282 non-null    int64
# ...

# %% [markdown]
# A continuación, se preesnta el recuento total de cada variable, su media, desvio estandar, valor minimo, valor maximo y  los valores porcentuales 25, 50 y 75 del conjunto de datos.
# La descripción de los datos se realiza mediante dos tablas con el fin de mostrar los descriptivos de todas las variabales del dataframe.

# %%
df.iloc[:,:15].describe()
# Out:
#                ID       CFC_1       CFC_2     CFC_3_I     CFC_4_I     CFC_5_I  \
# count  282.000000  282.000000  282.000000  282.000000  282.000000  282.000000
# mean   161.187943    5.315603    3.964539    2.702128    2.539007    2.184397
# std     93.921733    1.538256    1.813007    1.750423    1.616277    1.721139
# min      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%     78.250000    4.250000    3.000000    1.000000    1.000000    1.000000
# 50%    157.500000    6.000000    4.000000    2.000000    2.000000    1.000000
# 75%    242.750000    7.000000    5.000000    4.000000    3.000000    3.000000
# max    322.000000    7.000000    7.000000    7.000000    7.000000    7.000000
#
#             CFC_6       CFC_7       CFC_8     CFC_9_I    CFC_10_I    CFC_11_I  \
# count  282.000000  282.000000  282.000000  282.000000  282.000000  282.000000
# mean     4.152482    4.475177    4.943262    3.021277    2.492908    2.787234
# ...

# %%
df.iloc[:,15:].describe()
# Out:
#            Altura        Peso        Edad   Educacion  Ingreso_mensual  \
# count  282.000000  282.000000  282.000000  282.000000       282.000000
# mean     1.675993   68.719858   33.812057    2.929078         2.882979
# std      0.090910   14.630547   12.987133    1.097687         1.191814
# min      1.490000   43.000000   18.000000    1.000000         1.000000
# 25%      1.600000   58.000000   23.000000    2.000000         2.000000
# 50%      1.680000   65.500000   30.000000    3.000000         3.000000
# 75%      1.740000   78.750000   42.750000    3.000000         4.000000
# max      1.980000  125.000000   75.000000    6.000000         6.000000
#
#              Sexo  Frecuencia_verduras        Fuma
# count  282.000000           282.000000  282.000000
# mean     1.336879             3.297872    0.276596
# std      0.473484             0.874671    0.448110
# min      1.000000             0.000000    0.000000
# 25%      1.000000             3.000000    0.000000
# ...

# %% [markdown]
# # Parte 2: Escala Consideración de las consecuencias futuras
# ## Descripción de los ítems
#
# En esta sección vamos a trabajar con los 14 ítems de la escala Consideración de las Consecuencias Futuras.
# Se pretende:
# 1. Profundizar en la descripción de los ítems
# 2. Depurar los datos
# 3. Analizar los posibles factores latentes
# 4. Relacionar los factores obtenidos con las variables del dataframe
#
# Para comenzar con este ejercicio, vamos a guardar en df_CFC los items de la escala y explorar los datos

# %%
df_CFC = df.loc[ : , ['CFC_1', 'CFC_2', 'CFC_3_I', 'CFC_4_I', 'CFC_5_I', 'CFC_6', 'CFC_7','CFC_8',
                      'CFC_9_I', 'CFC_10_I', 'CFC_11_I', 'CFC_12_I', 'CFC_13', 'CFC_14']]
df_CFC
# Out:
#      CFC_1  CFC_2  CFC_3_I  CFC_4_I  CFC_5_I  CFC_6  CFC_7  CFC_8  CFC_9_I  \
# 0        3      6        4        5        2      5      3      5        3
# 1        6      6        1        1        1      4      7      6        1
# 2        7      1        1        1        2      4      1      1        7
# 3        4      3        4        5        2      5      6      5        2
# 4        7      2        1        2        1      6      7      7        2
# ..     ...    ...      ...      ...      ...    ...    ...    ...      ...
# 277      5      7        6        6        7      6      7      7        6
# 278      7      7        1        1        7      7      7      1        7
# 279      7      4        1        1        7      1      7      4        7
# 280      5      3        4        2        1      5      3      6        3
# 281      3      4        5        4        3      5      5      3        4
#
#      CFC_10_I  CFC_11_I  CFC_12_I  CFC_13  CFC_14
# ...

# %%
df_CFC.isnull().sum()
# Out:
# CFC_1       0
# CFC_2       0
# CFC_3_I     0
# CFC_4_I     0
# CFC_5_I     0
# CFC_6       0
# CFC_7       0
# CFC_8       0
# CFC_9_I     0
# CFC_10_I    0
# CFC_11_I    0
# CFC_12_I    0
# CFC_13      0
# CFC_14      0
# dtype: int64

# %% [markdown]
# No hay valores perdidos, por eso no se imputan ni eliminan a sujetos.
#
# A continuación, se exploran los datos mediante un boxplot y patrón de correlación inter-item.

# %%
#Change size of a boxplot
#https://www.delftstack.com/howto/seaborn/size-of-seaborn-plot/
sns.set(rc = {'figure.figsize':(13,8)})

ax = sns.boxplot(data=df_CFC)

# %% [markdown]
# En el diagrama de cajas se obervan posibles outlier en el ítem 4, 5 y 13 (casos mayores a 1,5 veces el Rango Intercuartílico, usualmente conocido como IQR).
# Se continuará trabajando con todos los datos, dado que el análisis que se realizó previamente era a nivel item.
# Posteriormente, se evaluará si es necesario excluir casos en los factores latentes de estas variables observadas.

# %%
corr_df = df_CFC.corr(method='pearson').round(2)
plt.figure(figsize=(10, 8))
sns.heatmap(corr_df, annot=True)
plt.show()

# %% [markdown]
# En el gráfico anterior se observa las correlaciones inter-item de la CFC. Los items que refieren a lo inmediato presentan una correlacion positiva con los demas items que refieren a lo inmediato, mismo patron se observa con los items referidos al futuro. A su vez, los items imediatos reportan una correlacion negativa con los items futuros.

# %% [markdown]
# ## Analisis de factores
#
# https://www.datacamp.com/tutorial/introduction-factor-analysis
#
# A cotninuación, se realiza un analisis factorial, con el fin de identificar las variables latentes que sean compuestos por los items de la escala CFC. Se realiza este tipo de analisis dado que se asume que existen facotres subyacentes a los valores observados, en este caso, los items de la CFC.

# %%
scaler = StandardScaler()
CFC_escalado = pd.DataFrame(scaler.fit_transform(df_CFC), 
             columns=['CFC_1', 'CFC_2', 'CFC_3_I', 'CFC_4_I', 'CFC_5_I', 'CFC_6', 'CFC_7','CFC_8',
                      'CFC_9_I', 'CFC_10_I', 'CFC_11_I', 'CFC_12_I', 'CFC_13', 'CFC_14'])
CFC_escalado
# Out:
#         CFC_1     CFC_2   CFC_3_I   CFC_4_I   CFC_5_I     CFC_6     CFC_7  \
# 0   -1.508019  1.124695  0.742780  1.525337 -0.107327  0.453605 -0.862818
# 1    0.445708  1.124695 -0.974138 -0.953885 -0.689371 -0.081611  1.476746
# 2    1.096951 -1.638057 -0.974138 -0.953885 -0.107327 -0.081611 -2.032600
# 3   -0.856776 -0.532956  0.742780  1.525337 -0.107327  0.453605  0.891855
# 4    1.096951 -1.085507 -0.974138 -0.334080 -0.689371  0.988821  1.476746
# ..        ...       ...       ...       ...       ...       ...       ...
# 277 -0.205534  1.677245  1.887392  2.145143  2.802891  0.988821  1.476746
# 278  1.096951  1.677245 -0.974138 -0.953885  2.802891  1.524037  1.476746
# 279  1.096951  0.019594 -0.974138 -0.953885  2.802891 -1.687259  1.476746
# 280 -0.205534 -0.532956  0.742780 -0.334080 -0.689371  0.453605 -0.862818
# 281 -1.508019  0.019594  1.315086  0.905532  0.474716  0.453605  0.306964
#
#         CFC_8   CFC_9_I  CFC_10_I  CFC_11_I  CFC_12_I    CFC_13    CFC_14
# ...

# %% [markdown]
# ### Pruebas de adecuación de los datos
# A continuación, se evalua la adecuación de los datos para realizar un analisis factorial. Para esto se realiza: Prueba de Bartlett y Prueba de Kaiser-Meyer-Olkin (KMO)

# %%
chi_square_value,p_value=calculate_bartlett_sphericity(CFC_escalado)
print("Esfericidad de Barlett :", chi_square_value.round(2), "con un p valor :", p_value.round(2))

kmo_all,kmo_model=calculate_kmo(CFC_escalado)
print("KMO: ", kmo_model.round(2))
# Out:
# Esfericidad de Barlett : 841.48 con un p valor : 0.0
# KMO:  0.75

# %% [markdown]
# La adecuación de la matriz fue confirmada con valores de la esfericidad de Bartlett de 841.48 con p < .01 y un Kaiser-Meyer-Olkin de 0.75. Estos valores indican que se puede continuar con el análisis de la estructura factorial.

# %% [markdown]
# ### Selección de número de factores latentes
#
# https://www.analyticsvidhya.com/blog/2020/10/dimensionality-reduction-using-factor-analysis-in-python/
#
#
# https://medium.com/@hongwy1128/intro-guide-to-factor-analysis-python-84dd0b0fd729

# %% [markdown]
# A continuación, se realiza una curva elbow (o curva de codo) para explorar cuál sería el valor óptimo de factores

# %%
fa = FactorAnalyzer(rotation = "varimax",  method = "ml", n_factors=CFC_escalado.shape[1]) 
fa.fit(CFC_escalado)
ev,_ = fa.get_eigenvalues()
plt.scatter(range(1,CFC_escalado.shape[1]+1),ev)
plt.plot(range(1,CFC_escalado.shape[1]+1),ev)
plt.title('Gráfico de sedimentación')
plt.xlabel('Factores')
plt.ylabel('Autovalores')
#plt.grid()
# Out:
# Text(0, 0.5, 'Autovalores')

# %% [markdown]
# En el gráfico, podemos ver que los autovalores descienden por debajo de 1 desde el 3er factor. A continuación se evalua las varianza explicada de cada modelo.

# %%
print('Varianza explicada del primer modelo \n', 
      pd.DataFrame(fa_3.get_factor_variance(),index=['Varianza','Varianza proporcional','Varianza acumulada']))
# Out:
# Varianza explicada del primer modelo
#                                0         1         2
# Varianza               2.160589  2.025005  0.709186
# Varianza proporcional  0.154328  0.144643  0.050656
# Varianza acumulada     0.154328  0.298971  0.349627

# %%
print('Varianza explicada del segundo modelo \n',
      pd.DataFrame(fa_2.get_factor_variance(),index=['Varianza','Varianza proporcional','Varianza acumulada']))
# Out:
# Varianza explicada del segundo modelo
#                                0         1
# Varianza               2.165550  2.047351
# Varianza proporcional  0.154682  0.146239
# Varianza acumulada     0.154682  0.300922

# %% [markdown]
# El primer modelo testeado logra expocar el 35% de la varianza total.
#
# Mientras que el seugndo modelo logra explicar el 30% de la varianza total. Al comparar los modelos, se puede deducir que el tercer factor del segundo modelo logra aumentar unicamente un 5% de la varianza total explicada.

# %%
fa_3 = FactorAnalyzer(n_factors=3, rotation='varimax')
fa_3.fit(CFC_escalado)
print(pd.DataFrame(fa_3.loadings_,index=CFC_escalado.columns).round(2))
# Out:
#              0     1     2
# CFC_1    -0.27  0.44  0.01
# CFC_2    -0.13  0.44  0.08
# CFC_3_I   0.50 -0.27  0.25
# CFC_4_I   0.59 -0.18  0.21
# CFC_5_I   0.41  0.03 -0.03
# CFC_6    -0.00  0.34  0.24
# CFC_7    -0.11  0.41  0.54
# CFC_8    -0.16  0.32  0.18
# CFC_9_I   0.49 -0.14 -0.32
# CFC_10_I  0.52 -0.16 -0.28
# CFC_11_I  0.77 -0.18 -0.08
# CFC_12_I  0.40  0.04 -0.12
# CFC_13    0.00  0.60  0.09
# CFC_14    0.03  0.84 -0.02

# %%
fa_2 = FactorAnalyzer(n_factors=2, rotation='varimax')
fa_2.fit(CFC_escalado)
print(pd.DataFrame(fa_2.loadings_,index=CFC_escalado.columns).round(2))
# Out:
#              0     1
# CFC_1    -0.27  0.43
# CFC_2    -0.14  0.45
# CFC_3_I   0.46 -0.19
# CFC_4_I   0.56 -0.11
# CFC_5_I   0.42  0.03
# CFC_6    -0.02  0.39
# CFC_7    -0.14  0.48
# CFC_8    -0.18  0.35
# CFC_9_I   0.49 -0.20
# CFC_10_I  0.53 -0.21
# CFC_11_I  0.79 -0.17
# CFC_12_I  0.41  0.02
# CFC_13   -0.01  0.61
# CFC_14    0.01  0.78

# %% [markdown]
# En el primer modelo, con tres factores latentes, se observa que unicamente dos items tienen una carga mayor a .30: item 7 con una saturación de .54 e item 9 con una saturación de -.32. Estos ítems corresponden a la consideración de la consecuencia futura e inmediata respectivamente.
#
#
# En el segundo modelo, con dos factores latentes, en el primer factor cargan todos los ítems referidos a los resultados inmediatos, con cargas positivas y mayores a .30. Mientras que en el segundo factor cargan todos los ítems referidos a los resutlados distantes, con cargas positivas y mayores a .30 Los resultados del modelo con dos factores es el esperado segun la literatura previa.
#
# Considerando las cargas factoriales, varianza explicada y la literatura previa, se continuará con el modelo de dos factores.

# %% [markdown]
# ### Calculo de variables latentes

# %%
df['CFC_I'] = ((df_CFC['CFC_3_I'] + df_CFC['CFC_4_I'] + df_CFC['CFC_5_I'] + df_CFC['CFC_9_I'] +
               df_CFC['CFC_10_I'] + df_CFC['CFC_11_I'] + df_CFC['CFC_12_I']) / 7 )

df['CFC_F'] = ((df_CFC['CFC_1'] + df_CFC['CFC_2'] + df_CFC['CFC_6'] + df_CFC['CFC_7'] +
               df_CFC['CFC_8'] + df_CFC['CFC_13'] + df_CFC['CFC_14']) / 7 )

df.head(5)
# Out:
#     ID  CFC_1  CFC_2  CFC_3_I  CFC_4_I  CFC_5_I  CFC_6  CFC_7  CFC_8  CFC_9_I  \
# 0  213      3      6        4        5        2      5      3      5        3
# 1   14      6      6        1        1        1      4      7      6        1
# 2   22      7      1        1        1        2      4      1      1        7
# 3   27      4      3        4        5        2      5      6      5        2
# 4   29      7      2        1        2        1      6      7      7        2
#
#    ...  Edad  Educacion  Ingreso_mensual  Sexo  Frecuencia_Frutas  \
# 0  ...    46          3                3     1                  3
# 1  ...    45          2                1     1                  4
# 2  ...    18          1                2     1                  3
# 3  ...    18          2                1     1                  2
# 4  ...    45          2                3     1                  4
#
#    Frecuencia_verduras  Bebidas_azucaradas  Fuma     CFC_I     CFC_F
# ...

# %% [markdown]
# ###  Descripción y depuración de datos de las variables latentes
#
# A continuación, se realiza la depuración de los factores latentes mediante el calculo de las puntuaciones Z, y rango intercuartílico

# %%
df_Factores = df.loc[ : , ['CFC_I', 'CFC_F']]
df_Factores
# Out:
#         CFC_I     CFC_F
# 0    3.857143  4.142857
# 1    1.285714  6.000000
# 2    3.428571  3.285714
# 3    3.000000  4.571429
# 4    2.428571  6.142857
# ..        ...       ...
# 277  5.428571  6.000000
# 278  3.571429  6.142857
# 279  2.714286  5.285714
# 280  2.142857  5.000000
# 281  3.571429  4.142857
#
# [282 rows x 2 columns]

# %%
z = np.abs(stats.zscore(df_Factores))
df_CFC = df_Factores[(z <3).all(axis = 1)]
print('ID de los casos con puntuación Z mayor a 3 \n',np.where(z > 3))
print('ID de los casos con puntuación Z menor a 3 \n', np.where(z < -3))
# Out:
# ID de los casos con puntuación Z mayor a 3
#  (array([], dtype=int64), array([], dtype=int64))
# ID de los casos con puntuación Z menor a 3
#  (array([], dtype=int64), array([], dtype=int64))

# %% [markdown]
# No hay casos con puntuacion Z mayor a 3. Por lo cual, no se eliminan valores por este criterio.
#
#
# A continuación, se explora los datos mediante un boxplot y se realiza la depuración de datos mediante el rango intercuartílico
#
# PuntuacionZ: https://statologos.com/remove-outliers-python/
#
# https://www.kutombawewe.com/es/python/detectar-y-excluir-valores-atipicos-en-el-marco-de-datos-de-pandas/1046331960/amp/
#
#
#
#
# Dibujar el boxplot: https://www.python-graph-gallery.com/30-basic-boxplot-with-seaborn
#
# Encontrar los outliers en el boxplot: https://www.geeksforgeeks.org/finding-the-outlier-points-from-matplotlib/

# %%
sns.set(style="darkgrid", rc = {'figure.figsize':(10,5)})
sns.boxplot(data=df_Factores)
plt.show()

# %%
q1 = np.quantile(df.CFC_I, 0.25)
q3 = np.quantile(df.CFC_I, 0.75)
med = np.median(df.CFC_I)
iqr = q3-q1
upper_bound = q3+(1.5*iqr)
lower_bound = q1-(1.5*iqr)
outliers = df.CFC_I[(df.CFC_I <= lower_bound) | (df.CFC_I >= upper_bound)]
print('Los casos con valores atípicos en CFC_I son:\n',outliers)
# Out:
# Los casos con valores atípicos en CFC_I son:
#  245    5.428571
# 270    5.428571
# 277    5.428571
# Name: CFC_I, dtype: float64

# %%
df = df.drop([245, 270, 277])

# %% [markdown]
# Se encontraron 3 casos identificados como outliers mediante el calculo del rango intercuartílico. A continuación, se vizualiza el bloxplot de CFC_I para verificar si se eliminaron correctamente los outliers.

# %%
sns.set(style="darkgrid", rc = {'figure.figsize':(10,5)})
sns.boxplot(data=df.CFC_I)
plt.show()

# %% [markdown]
# ## Testeo de modelos
# ###  Modelo 1: La subescala imediata de la CFC predice el indice de masa corporal?
# https://realpython.com/linear-regression-in-python/
#
#
# https://seaborn.pydata.org/tutorial/regression.html
#
#
# Change size of a boxplot
# https://www.delftstack.com/howto/seaborn/size-of-seaborn-plot/

# %% [markdown]
# A continuacón, se calcula la variable "Indice de Masa Corporal" (IMC), variable que será incorporada como variable dependiente en los modelos de este estudio.
# En este modelo, también se incluirá la CFC, Edad, Educacion e ingreso mensual. Para esto, se crea df_Regresion, con el fin de facilitar el análisis.

# %%
df['IMC'] = df.Peso/df.Altura**2
df.head(5)
# Out:
#     ID  CFC_1  CFC_2  CFC_3_I  CFC_4_I  CFC_5_I  CFC_6  CFC_7  CFC_8  CFC_9_I  \
# 0  213      3      6        4        5        2      5      3      5        3
# 1   14      6      6        1        1        1      4      7      6        1
# 2   22      7      1        1        1        2      4      1      1        7
# 3   27      4      3        4        5        2      5      6      5        2
# 4   29      7      2        1        2        1      6      7      7        2
#
#    ...  Educacion  Ingreso_mensual  Sexo  Frecuencia_Frutas  \
# 0  ...          3                3     1                  3
# 1  ...          2                1     1                  4
# 2  ...          1                2     1                  3
# 3  ...          2                1     1                  2
# 4  ...          2                3     1                  4
#
#    Frecuencia_verduras  Bebidas_azucaradas  Fuma     CFC_I     CFC_F  \
# ...

# %%
df_Regresion = df.loc[ : , ['CFC_I', 'CFC_F', 'Edad', 'Educacion', 'Ingreso_mensual', 'IMC']]
df_Regresion.tail(5)
# Out:
#         CFC_I     CFC_F  Edad  Educacion  Ingreso_mensual        IMC
# 276  2.142857  4.428571    61          6                6  26.729927
# 278  3.571429  6.142857    60          5                2  29.402273
# 279  2.714286  5.285714    65          2                5  24.341758
# 280  2.142857  5.000000    49          4                6  27.770313
# 281  3.571429  4.142857    30          1                3  24.691358

# %%
df_Regresion.isnull().sum()
# Out:
# CFC_I              0
# CFC_F              0
# Edad               0
# Educacion          0
# Ingreso_mensual    0
# IMC                0
# dtype: int64

# %% [markdown]
# Eliminar los outliers mediante el calculo de su puntuación Z

# %%
df_Regresion = df_Regresion[(np.abs(stats.zscore(df_Regresion)) < 3).all(axis=1)]
df_Regresion.tail(5)
# Out:
#         CFC_I     CFC_F  Edad  Educacion  Ingreso_mensual        IMC
# 276  2.142857  4.428571    61          6                6  26.729927
# 278  3.571429  6.142857    60          5                2  29.402273
# 279  2.714286  5.285714    65          2                5  24.341758
# 280  2.142857  5.000000    49          4                6  27.770313
# 281  3.571429  4.142857    30          1                3  24.691358

# %%
#Eliminar outliers de las variables de interés
Q1 = df_Regresion.quantile (q = .25)
Q3 = df_Regresion.quantile (q = .75)
IQR = df_Regresion.apply (stats.iqr)

df_Regresion = df_Regresion [~ ((df_Regresion <(Q1-1.5 * IQR)) | (df_Regresion> (Q3 + 1.5 * IQR))). any (axis = 1)]

#Diagrama de caja de las variables transformadas
ax = sns.boxplot(data=df_Regresion)

# %%
df_Regresion.tail(5)
# Out:
#         CFC_I     CFC_F  Edad  Educacion  Ingreso_mensual        IMC
# 274  2.571429  3.142857    45          1                3  25.969529
# 275  3.285714  5.285714    22          2                3  27.885187
# 279  2.714286  5.285714    65          2                5  24.341758
# 280  2.142857  5.000000    49          4                6  27.770313
# 281  3.571429  4.142857    30          1                3  24.691358

# %%
scaler = StandardScaler()
df_Regresion_escalado = scaler.fit_transform(df_Regresion)
df_Regresion_escalado = pd.DataFrame(df_Regresion_escalado, columns=['CFC_I', 'CFC_F', 'Edad', 'Educacion', 'Ingreso_mensual_promedio_liquido', 'IMC'])
df_Regresion_escalado

# %% [markdown]
# Se explora las correlaciones de las variables de este análisis.

# %%
corr_df = df_Regresion_escalado.corr(method='pearson').round(2)
plt.figure(figsize=(10, 8))
sns.heatmap(corr_df, annot=True)
plt.show()

# %%
# Out:
#         CFC_I     CFC_F      Edad  Educacion  \
# 0    1.180610 -0.598976  1.191548   0.228218
# 1   -1.351681  1.318928  1.106120  -0.912871
# 2    0.758562 -1.484163 -1.200433  -2.053960
# 3    0.336513 -0.156383 -1.200433  -0.912871
# 4   -0.226218  1.466460  1.106120  -0.912871
# ..        ...       ...       ...        ...
# 245 -0.085535 -1.631694  1.106120  -2.053960
# 246  0.617879  0.581273 -0.858721  -0.912871
# 247  0.055148  0.581273  2.814678  -0.912871
# 248 -0.507584  0.286210  1.447832   1.369306
# 249  0.899245 -0.598976 -0.175298  -2.053960
#
#      Ingreso_mensual_promedio_liquido       IMC
# 0                            0.129915  0.104044
# 1                           -1.579489  1.041705
# 2                           -0.724787 -1.481557
# 3                           -1.579489 -0.689884
# 4                            0.129915  1.550015
# ..                                ...       ...
# 245                          0.129915  0.637426
# ...

# %% [markdown]
# #Diagrama de caja de las variables transformadas
# ax = sns.boxplot(data=df_Regresion_escalado_IQR)

# %% [markdown]
# corr_df = df_Regresion_escalado_IQR.corr(method='pearson').round(2)
# plt.figure(figsize=(10, 8))
# sns.heatmap(corr_df, annot=True)
# plt.show()

# %%
corr_df = df_Regresion_escalado.corr(method='pearson').round(2)
plt.figure(figsize=(10, 8))
sns.heatmap(corr_df, annot=True)
plt.show()

# %% [markdown]
# ## Modelos de regresión para evaluar la prediccón de IMC

# %% [markdown]
# A continuación, se divide el conjunto de datos en conjunto de entrenamiento y conjunto de prueba.
# El 30% ira al conjunto de prueba y el 70% al conjunto de entrenamientp

# %% [markdown]
# #### Modelo de regresión para evaluar si  CFC_I predice el IMC

# %%
sns.lmplot(x="CFC_I", y="IMC", data=df_Regresion_escalado)
#Evaluar las correlaciones entre las variables depuradas

display(pg.corr(df_Regresion_escalado['CFC_I'], df_Regresion_escalado['IMC'], method='pearson'))
# Out:
#            n         r         CI95%     p-val   BF10     power
# pearson  277  0.171451  [0.05, 0.28]  0.004212  4.419  0.818856

# %%
X_CFC_I = df_Regresion['CFC_I'].values.reshape(-1,1)
y_CFC_I = df_Regresion['IMC'].values.reshape(-1,1)

X_train_CFC_I, X_test_CFC_I, y_train_CFC_I, y_test_CFC_I = train_test_split(X_CFC_I, y_CFC_I, test_size=0.3, random_state=0)

#shapes of splitted data
print("X_train:",X_train_CFC_I.shape)
print("X_test:",X_test_CFC_I.shape)
print("Y_train:",y_train_CFC_I.shape)
print("Y_test:",y_test_CFC_I.shape)
# Out:
# X_train: (193, 1)
# X_test: (84, 1)
# Y_train: (193, 1)
# Y_test: (84, 1)

# %%
#Next, we need to create an instance of the Linear Regression Python object. 
#We will assign this to a variable called model. Here is the code for this:
regressor_CFC_I = LinearRegression() 
regressor_CFC_I.fit(X_train_CFC_I, y_train_CFC_I) #Entrena el algoritmo 

#Para obtener el intercepto:
print(regressor_CFC_I.intercept_)


#Para obtener la pendiente
print(regressor_CFC_I.coef_)
# Out:
# [22.99107895]
# [[0.47723192]]

# %% [markdown]
# El valor anterior indica que CFC_I aumenta en 1 unidad, el IMC aumenta un 0.37

# %%
y_pred_CFC_I = regressor_CFC_I.predict(X_test_CFC_I)

df_transformados_CFC_I = pd.DataFrame({'Actual': y_test_CFC_I.flatten(), 'Predicted': y_pred_CFC_I.flatten()})
df_transformados_CFC_I = df_transformados_CFC_I.head(25)

df_transformados_CFC_I.plot(kind='bar',figsize=(10,8))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %%
print(regressor_CFC_I.coef_)
# Out:
# [[0.47723192]]

# %% [markdown]
# El valor anterior indica que CFC_I aumenta en 1 unidad, el IMC aumenta un 0.37

# %%
print('Modelo 1: ¿CFC-I predice el IMC?: ')
print('Mean Absolute Error (MAE):', metrics.mean_absolute_error(y_test_CFC_I, y_pred_CFC_I).round(3)) 
print('Mean Squared Error (MSE):', metrics.mean_squared_error(y_test_CFC_I, y_pred_CFC_I).round(3)) 
print('Root Mean Squared Error (RMSE):', np.sqrt(metrics.mean_squared_error(y_test_CFC_I, y_pred_CFC_I)).round(3))
# Out:
# Modelo 1: ¿CFC-I predice el IMC?:
# Mean Absolute Error (MAE): 2.85
# Mean Squared Error (MSE): 13.397
# Root Mean Squared Error (RMSE): 3.66

# %% [markdown]
# #### Modelo de regresión para evaluar si  CFC_F predice el IMC

# %%
sns.lmplot(x="CFC_F", y="IMC", data=df_Regresion_escalado)
#Evaluar las correlaciones entre las variables depuradas

display(pg.corr(df_Regresion_escalado['CFC_F'], df_Regresion_escalado['IMC'], method='pearson'))
# Out:
#            n         r          CI95%     p-val   BF10     power
# pearson  277  0.063988  [-0.05, 0.18]  0.288579  0.132  0.185871

# %% [markdown]
# #### Modelo de regresión multiple
#
#
# https://towardsdatascience.com/stepwise-regression-tutorial-in-python-ebf7c782c922

# %%
x_RM =df_Regresion_escalado.iloc[:,:5]

y_RM =df_Regresion_escalado.IMC

# %%
x_RM
# Out:
#         CFC_I     CFC_F      Edad  Educacion  Ingreso_mensual_promedio_liquido
# 0    1.069624 -0.619426  1.000111   0.062682                          0.093893
# 1   -1.324068  1.236275  0.920505  -0.851156                         -1.584063
# 2    0.670675 -1.475903 -1.228872  -1.764994                         -0.745085
# 3    0.271727 -0.191187 -1.228872  -0.851156                         -1.584063
# 4   -0.260205  1.379021  0.920505  -0.851156                          0.093893
# ..        ...       ...       ...        ...                               ...
# 272  2.532436  1.236275  1.318537   0.062682                          0.093893
# 273  0.803658  1.379021  2.114603   1.890358                         -0.745085
# 274  0.005761  0.522544  2.512635  -0.851156                          1.771849
# 275 -0.526171  0.237051  1.238931   0.976520                          2.610827
# 276  0.803658 -0.619426 -0.273594  -1.764994                          0.093893
#
# [277 rows x 5 columns]

# %%
#Caclcular VIF de las variables de interés
def calc_vif(X):
    vif = pd.DataFrame()
    vif["variables"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    return(vif)

X = df_Regresion_escalado.iloc[:,:-1]

round(calc_vif(X),3)
# Out:
#                           variables    VIF
# 0                             CFC_I  1.250
# 1                             CFC_F  1.151
# 2                              Edad  1.424
# 3                         Educacion  1.101
# 4  Ingreso_mensual_promedio_liquido  1.406

# %% [markdown]
# Los valores VIF están en el rango esperado. Es importante recordar que un valor entre 1 y 5 indica una correlación moderada entre las variables del en el modelo. Los VIF de las variables no presentan elevada multicolinealidad. Valores que no son lo suficientemente grave como para requerir atención.
#
# A continuación, se visualiza el diagrama de puntos de las variables a utilizar en el modelo de regresión. Este diagrama tiene los datos puros (es decir, sin depurar)

# %%
## creating function to get model statistics

def get_stats():
    results = sm.OLS(y_RM, x_RM).fit()
    print(results.summary())
get_stats()
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                    IMC   R-squared (uncentered):                   0.259
# Model:                            OLS   Adj. R-squared (uncentered):              0.246
# Method:                 Least Squares   F-statistic:                              19.04
# Date:                Thu, 29 Sep 2022   Prob (F-statistic):                    3.09e-16
# Time:                        15:55:54   Log-Likelihood:                         -351.48
# No. Observations:                 277   AIC:                                      713.0
# Df Residuals:                     272   BIC:                                      731.1
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# ...

# %%
x_RM = x_RM.drop(['Ingreso_mensual_promedio_liquido'], axis=1)

get_stats()
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                    IMC   R-squared (uncentered):                   0.259
# Model:                            OLS   Adj. R-squared (uncentered):              0.248
# Method:                 Least Squares   F-statistic:                              23.83
# Date:                Thu, 29 Sep 2022   Prob (F-statistic):                    6.45e-17
# Time:                        15:55:54   Log-Likelihood:                         -351.57
# No. Observations:                 277   AIC:                                      711.1
# Df Residuals:                     273   BIC:                                      725.6
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
x_RM = x_RM.drop(['CFC_F'], axis=1)

get_stats()
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                    IMC   R-squared (uncentered):                   0.255
# Model:                            OLS   Adj. R-squared (uncentered):              0.247
# Method:                 Least Squares   F-statistic:                              31.22
# Date:                Thu, 29 Sep 2022   Prob (F-statistic):                    2.16e-17
# Time:                        15:55:54   Log-Likelihood:                         -352.32
# No. Observations:                 277   AIC:                                      710.6
# Df Residuals:                     274   BIC:                                      721.5
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
x_RM = x_RM.drop(['CFC_I'], axis=1)

get_stats()
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                    IMC   R-squared (uncentered):                   0.253
# Model:                            OLS   Adj. R-squared (uncentered):              0.247
# Method:                 Least Squares   F-statistic:                              46.52
# Date:                Thu, 29 Sep 2022   Prob (F-statistic):                    3.95e-18
# Time:                        15:55:54   Log-Likelihood:                         -352.68
# No. Observations:                 277   AIC:                                      709.4
# Df Residuals:                     275   BIC:                                      716.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
# https://www.analyticsvidhya.com/blog/2022/03/multiple-linear-regression-using-python/
X_RM = df_Regresion.iloc[:,2:4]
X_RM
# Out:
#      Edad  Educacion
# 0      46          3
# 1      45          2
# 2      18          1
# 3      18          2
# 4      45          2
# ..    ...        ...
# 277    50          3
# 278    60          5
# 279    65          2
# 280    49          4
# 281    30          1
#
# [277 rows x 2 columns]

# %%
y_RM = df_Regresion['CFC_I'].values.reshape(-1,1)
X_train_RM, X_test_RM, y_train_RM, y_test_RM = train_test_split(X_RM, y_RM, test_size=0.3, random_state=0)

#shapes of splitted data
print("X_train:",X_train_RM.shape)
print("X_test:",X_test_RM.shape)
print("Y_train:",y_train_RM.shape)
print("Y_test:",y_test_RM.shape)



#Next, we need to create an instance of the Linear Regression Python object. 
#We will assign this to a variable called model. Here is the code for this:
regressor_RM = LinearRegression() 
regressor_RM.fit(X_train_RM, y_train_RM) #Entrena el algoritmo 

y_pred_RM =regressor_RM.predict(X_test_RM)

#Para obtener el intercepto:
print(regressor_RM.intercept_)


#Para obtener la pendiente
print(regressor_RM.coef_)
# Out:
# X_train: (193, 2)
# X_test: (84, 2)
# Y_train: (193, 1)
# Y_test: (84, 1)
# [2.91756492]
# [[ 0.01805128 -0.28976555]]

# %%
y_test_RM = numpy.squeeze(y_test_RM)
y_pred_RM = numpy.squeeze(y_pred_RM)

pred_df=pd.DataFrame({'Actual Value':y_test_RM,'Predicted Value':y_pred_RM,'Difference':y_test_RM-y_pred_RM})
pred_df
# Out:
#     Actual Value  Predicted Value  Difference
# 0       1.857143         2.244942   -0.387799
# 1       2.142857         2.914730   -0.771872
# 2       2.142857         2.463448   -0.320591
# 3       3.571429         2.300041    1.271388
# 4       4.857143         2.589807    2.267336
# ..           ...              ...         ...
# 79      3.000000         2.968883    0.031117
# 80      1.571429         2.173682   -0.602254
# 81      4.714286         2.716166    1.998120
# 82      4.571429         1.720510    2.850919
# 83      2.714286         2.463448    0.250838
#
# [84 rows x 3 columns]

# %%
Accuracy=r2_score(y_test_RM,y_pred_RM)*100
print(" Accuracy of the model is %.2f" %Accuracy)
# Out:
#  Accuracy of the model is -0.49

# %%
print('Modelo 2: ¿Qué variables predicen el IMC?: ')
print('Mean Absolute Error (MAE):', metrics.mean_absolute_error(y_test_RM, y_pred_RM).round(3)) 
print('Mean Squared Error (MSE):', metrics.mean_squared_error(y_test_RM, y_pred_RM).round(3)) 
print('Root Mean Squared Error (RMSE):', np.sqrt(metrics.mean_squared_error(y_test_RM, y_pred_RM)).round(3))
# Out:
# Modelo 2: ¿Qué variables predicen el IMC?:
# Mean Absolute Error (MAE): 0.844
# Mean Squared Error (MSE): 1.125
# Root Mean Squared Error (RMSE): 1.061

# %% [markdown]
# ### Modelo con un árbol de clasificación

# %%
#x_RM = x_RM.drop(['Ingreso_mensual_promedio_liquido'], axis=1)
#Como ver las correlaciones de una variable contra el resto
# https://datascience.stackexchange.com/questions/39137/how-can-i-check-the-correlation-between-features-and-target-variable

# %%
df_arbol = df.drop(['ID','CFC_1', 'CFC_2', 'CFC_3_I', 'CFC_4_I', 'CFC_5_I', 'CFC_6',
       'CFC_7', 'CFC_8', 'CFC_9_I', 'CFC_10_I', 'CFC_11_I', 'CFC_12_I',
       'CFC_13', 'CFC_14', 'Altura', 'Peso'], axis=1)
corr_matrix = df_arbol.corr()
print(corr_matrix["IMC"].sort_values(ascending=False))
# Out:
# IMC                    1.000000
# Edad                   0.442659
# CFC_I                  0.144589
# Ingreso_mensual        0.142039
# Sexo                   0.131882
# CFC_F                  0.082608
# Fuma                   0.024890
# Frecuencia_verduras   -0.060387
# Educacion             -0.136346
# Name: IMC, dtype: float64

# %%
#copiar variables a un nuevo dataframe 
#https://datascience.stackexchange.com/questions/39137/how-can-i-check-the-correlation-between-features-and-target-variable

# %%
df_Arbol = df[['IMC', 'Edad', 'CFC_I','Ingreso_mensual',
              'Sexo', 'CFC_F', 'Fuma', 'Frecuencia_verduras', 'Educacion']].copy()

df_Arbol
# Out:
#            IMC  Edad     CFC_I  Ingreso_mensual  Sexo     CFC_F  Fuma  \
# 0    24.167162    46  3.857143                3     1  4.142857     0
# 1    27.335640    45  1.285714                1     1  6.000000     0
# 2    18.809206    18  3.428571                2     1  3.285714     0
# 3    21.484375    18  3.000000                1     1  4.571429     0
# 4    29.053288    45  2.428571                3     1  6.142857     1
# ..         ...   ...       ...              ...   ...       ...   ...
# 277  25.209201    50  5.428571                3     2  6.000000     1
# 278  29.402273    60  3.571429                2     2  6.142857     0
# 279  24.341758    65  2.714286                5     1  5.285714     0
# 280  27.770313    49  2.142857                6     2  5.000000     0
# 281  24.691358    30  3.571429                3     2  4.142857     1
#
#      Frecuencia_verduras  Educacion
# 0                      3          3
# 1                      4          2
# ...

# %%
df_Arbol.isnull().sum()
# Out:
# IMC                    0
# Edad                   0
# CFC_I                  0
# Ingreso_mensual        0
# Sexo                   0
# CFC_F                  0
# Fuma                   0
# Frecuencia_verduras    0
# Educacion              0
# dtype: int64

# %%
corr_df = df_Arbol.corr(method='pearson').round(2)
plt.figure(figsize=(10, 8))
sns.heatmap(corr_df, annot=True)
plt.show()

# %%
df_Arbol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 282 entries, 0 to 281
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   IMC                  282 non-null    float64
#  1   Edad                 282 non-null    int64
#  2   CFC_I                282 non-null    float64
#  3   Ingreso_mensual      282 non-null    int64
#  4   Sexo                 282 non-null    int64
#  5   CFC_F                282 non-null    float64
#  6   Fuma                 282 non-null    int64
#  7   Frecuencia_verduras  282 non-null    int64
#  8   Educacion            282 non-null    int64
# dtypes: float64(3), int64(6)
# memory usage: 20.0 KB

# %%
#enlace donde saque el arbol de regresion explica super bien cada paso
# https://data36.com/regression-tree-python-scikit-learn/

# %%
df_Arbol
# Out:
#            IMC  Edad     CFC_I  Ingreso_mensual  Sexo     CFC_F  Fuma  \
# 0    24.167162    46  3.857143                3     1  4.142857     0
# 1    27.335640    45  1.285714                1     1  6.000000     0
# 2    18.809206    18  3.428571                2     1  3.285714     0
# 3    21.484375    18  3.000000                1     1  4.571429     0
# 4    29.053288    45  2.428571                3     1  6.142857     1
# ..         ...   ...       ...              ...   ...       ...   ...
# 277  25.209201    50  5.428571                3     2  6.000000     1
# 278  29.402273    60  3.571429                2     2  6.142857     0
# 279  24.341758    65  2.714286                5     1  5.285714     0
# 280  27.770313    49  2.142857                6     2  5.000000     0
# 281  24.691358    30  3.571429                3     2  4.142857     1
#
#      Frecuencia_verduras  Educacion
# 0                      3          3
# 1                      4          2
# ...

# %% [markdown]
# No es necesario escalar los datos
#
# https://www.atoti.io/articles/when-to-perform-a-feature-scaling/
#
# https://www.quora.com/Decision-Tree-based-models-dont-require-scaling-How-does-scaling-impact-the-predictions-of-decision-tree-based-models

# %%
#https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeRegressor.html
# Create training and feature
X = df_Arbol.iloc[:,1:]
y = df_Arbol.IMC

# Split data

X_train_RT_1, X_test_RT_1, y_train_RT_1, y_test_RT_1 = train_test_split(X, y, test_size=0.3, random_state=44)

#Primero ajustemos un árbol de decisiones con parámetros predeterminados para tener una idea básica del rendimiento.
model = DecisionTreeRegressor(random_state=44)
model.fit(X_train_RT_1, y_train_RT_1)
y_pred_RT_1 = model.predict(X_test_RT_1)



plt.figure(figsize=(10,8), dpi=150)
plot_tree(model, feature_names=X.columns);

# %% [markdown]
# max_depth
# The first parameter to tune is max_depth. This indicates how deep the tree can be. The deeper the tree, the more splits it has and it captures more information about the data. We fit a decision tree with depths ranging from 1 to 32 and plot the training and test auc scores.
#
#
# min_samples_split
# min_samples_split represents the minimum number of samples required to split an internal node. This can vary between considering at least one sample at each node to considering all of the samples at each node. When we increase this parameter, the tree becomes more constrained as it has to consider more samples at each node. Here we will vary the parameter from 10% to 100% of the samples
#
#
# min_samples_leaf
# min_samples_leaf is The minimum number of samples required to be at a leaf node. This parameter is similar to min_samples_splits, however, this describe the minimum number of samples of samples at the leafs, the base of the tree.
#
#
# max_features
# max_features represents the number of features to consider when looking for the best split.

# %%
print('Modelo 3: Primer árbol de decisión ')
print('Mean Absolute Error (MAE):', metrics.mean_absolute_error(y_test_RT_1, y_pred_RT_1).round(3)) 
print('Mean Squared Error (MSE):', metrics.mean_squared_error(y_test_RT_1, y_pred_RT_1).round(3)) 
print('Root Mean Squared Error (RMSE):', np.sqrt(metrics.mean_squared_error(y_test_RT_1, y_pred_RT_1)).round(3))
# Out:
# Modelo 3: Primer árbol de decisión
# Mean Absolute Error (MAE): 4.524
# Mean Squared Error (MSE): 35.387
# Root Mean Squared Error (RMSE): 5.949

# %% [markdown]
# In classification, we saw that increasing the depth of the tree allowed us to get more complex decision boundaries. Let’s check the effect of increasing the depth in a regression setting:

# %%
model = DecisionTreeRegressor(random_state=44, max_depth=3)
model.fit(X_train_RT_1, y_train_RT_1)
predictions = model.predict(X_test_RT_1)

fig = plt.figure(figsize=(20,15))
plot_tree(model, fontsize=12, feature_names=X.columns, filled=True);

# %%
fig.savefig("decistion_tree.png")

# %% [markdown]
# x_columns.remove("Edad")
# #x_columns.remove("Edad")

# %% [markdown]
# def get_stats():
#     x = df_Regresion[x_columns]
#     results = sm.OLS(y, x).fit()
#     print(results.summary())
# get_stats()

# %% [markdown]
# x_columns.remove("CFC_F")
# #x_columns.remove("Edad")
# def get_stats():
#     x = df_Regresion[x_columns]
#     results = sm.OLS(y, x).fit()
#     print(results.summary())
# get_stats()

# %%
# SI NO BORRAR
# Ver si esto es importanet
#Identificamos cuantos valores perdidos hay
#df_CFC.isnull().sum()

# %% [markdown]
# #NO BORRAR POR LAS DUDAS
# df['AS_TOTAL'] = df['AS_TOTAL'].astype(int)
#
#
#
# #Functions for drawing linear regression models
# #Si quiero ver el diagra,a de caja por sexo
# #https://seaborn.pydata.org/tutorial/regression.html
# sns.lmplot(x="total_bill", y="tip", hue="smoker", data=tips);

# %% [markdown]
# ## Enlaces que me ayudaron:
#
# ### Carga de datos, manipulación y descripción de las variables
# Idenfiticar 999 como valores perdidos: https://elmundodelosdatos.com/identificacion-valores-perdidos-python/
#
# Evaluar los outliers: https://es.acervolima.com/detectar-y-eliminar-los-valores-atipicos-con-python/
#
#
# Regresion lineal: https://www.datasource.ai/es/data-science-articles/una-guia-para-principiantes-sobre-la-regresion-lineal-en-python-con-scikit-learn

# %% [markdown]
# #como convertir todo a percentil
# #https://stackoverflow.com/questions/54369807/how-can-i-categorize-all-columns-in-a-data-at-once-make-all-values-become-high
# df_Arbol = df_Regresion.loc[:,:].apply(lambda x: pd.qcut(x, q=[0, 0.25, 0.75, 1.0],
#                                     labels =['0','1','2']) )
#
# df_Arbol.head(10)

# %% [markdown]
# # Ver si lo dejo
# #### Regresión multinivel para evaluar qué variables predice el IMC

# %% [markdown]
# Definir X e Y
# Esto es como extraer variables dependientes e independientes.
#
# Tenemos que definir x e y para el modelo. xey son características de entrada y salida del conjunto de datos. Entonces, tomando x características como valores de entrada que son independientes, nuestro modelo predecirá el resultado que es y que son dependientes.
#
# https://www.analyticsvidhya.com/blog/2022/03/multiple-linear-regression-using-python/

# %%
X_train_RM,X_test_RM,y_train_RM,y_test_RM=train_test_split(x_RM_2,y_RM,test_size=0.3,random_state=0)

#shapes of splitted data
print("X_train:",X_train_RM.shape)
print("X_test:",X_test_RM.shape)
print("Y_train:",y_train_RM.shape)
print("Y_test:",y_test_RM.shape)
# Out:
# X_train: (193, 2)
# X_test: (84, 2)
# Y_train: (193,)
# Y_test: (84,)

# %%
#Train the Model
#To train the model, we have to import the Linear Regression model, which we have already created at the beginning. 
#Use the fit method, and pass the training sets into it to train the model.
regressor_RM=LinearRegression()
regressor_RM.fit(X_train_RM,y_train_RM)
# Out:
# LinearRegression()

# %%
#Predecir los resultados de la prueba
#Use el método de predicción para predecir los resultados, luego pase las variables independientes y vea los resultados.
#Dará la matriz con todos los valores en ella.

y_pred_RM=linreg.predict(X_test_RM)
y_pred_RM
# Out:
# D:\servidor\Anaconda\lib\site-packages\sklearn\base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names seen at fit time, yet now missing:
# - CFC_F
# - CFC_I
# - Ingreso_mensual_promedio_liquido
#
#   warnings.warn(message, FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\LUCAAL~1\AppData\Local\Temp/ipykernel_868/2284851920.py in <module>
#       3 #Dará la matriz con todos los valores en ella.
#       4
# ----> 5 y_pred_RM=linreg.predict(X_test_RM)
#       6 y_pred_RM
#
# D:\servidor\Anaconda\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     360             Returns predicted values.
#     361         """
# --> 362         return self._decision_function(X)
#     363
#     364     _preprocess_data = staticmethod(_preprocess_data)
# ...

# %%
#Evaluar el modelo
#Tenemos diferentes métricas para encontrar el puntaje de precisión del modelo, 
#y aquí usamos r2_score para evaluar nuestro modelo y encontrar su precisión.

Accuracy=r2_score(y_test_RM,y_pred_RM)*100
print(" Accuracy of the model is %.2f" %Accuracy)
# Out:
#  Accuracy of the model is 29.30

# %%
#Plot the Results
#We will plot the scatter plot between actual values and predicted values. 
#Use xlabel to label the x-axis and use ylabel to label the y-axis.

plt.scatter(y_test_RM,y_pred_RM);
plt.xlabel('Actual');
plt.ylabel('Predicted');

# %%
#Regression plot of our model.
#A regression plot is useful to understand the linear relationship between two parameters. 
#It creates a regression line in-between those parameters and then plots a scatter plot of those data points.

sns.regplot(x=y_test_RM,y=y_pred_RM,ci=None,color ='red');

# %%
#Predicted Values
#Let us create a new data frame that contains actual values, predicted values, and differences between them so
#that we will understand how near the model predicts its actual value

pred_df=pd.DataFrame({'Actual Value':y_test_RM,'Predicted Value':y_pred_RM,'Difference':y_test_RM-y_pred_RM})
pred_df
# Out:
#      Actual Value  Predicted Value  Difference
# 218      0.612564         0.736775   -0.124211
# 225     -0.966561        -0.364826   -0.601735
# 190     -1.040738         0.560628   -1.601366
# 15      -0.626937        -0.039272   -0.587665
# 55      -1.178269        -0.029187   -1.149083
# ..            ...              ...         ...
# 204      1.292874         0.701084    0.591790
# 103     -1.616306        -0.369250   -1.247057
# 71      -0.563506         0.259425   -0.822931
# 116      0.680955        -0.156480    0.837434
# 212     -0.710515        -0.572957   -0.137557
#
# [84 rows x 3 columns]
